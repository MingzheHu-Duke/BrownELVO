# %% [markdown]
# <a href="https://colab.research.google.com/github/MingzheHu-Duke/BrownELVO/blob/main/Brown_Map_keys.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import chardet
import pandas as pd

# %%
# Read in the elvo keys
with open('/content/elvos.key.csv', 'rb') as f:
    result = chardet.detect(f.read())  # or readline if the file is large


df_keys = pd.read_csv('/content/elvos.key.csv', encoding=result['encoding'])
df_keys.head(10)
# Out:
#   _StudyDateTime _SeriesDateTime  ... InstanceCreationDateTime StationName
# 0   9/8/18 18:20    9/8/18 18:20  ...             9/8/18 18:20     Unknown
# 1  6/26/18 15:58   6/26/18 15:58  ...            6/26/18 15:58     Unknown
# 2  6/17/16 12:38   6/17/16 12:38  ...            6/17/16 12:38     Unknown
# 3   4/7/17 19:09    4/7/17 19:09  ...             4/7/17 19:09     Unknown
# 4   4/8/19 17:43    4/8/19 17:43  ...             4/8/19 17:43     Unknown
# 5   5/7/17 22:19    5/7/17 22:19  ...             5/7/17 22:19     Unknown
# 6   5/5/18 20:20    5/5/18 20:20  ...             5/5/18 20:20     Unknown
# 7  10/25/17 4:07   10/25/17 4:07  ...            10/25/17 4:07     Unknown
# 8   8/17/18 8:52    8/17/18 8:52  ...             8/17/18 8:52     Unknown
# 9   9/7/19 14:11    9/7/19 14:11  ...             9/7/19 14:11     Unknown
#
# [10 rows x 22 columns]

# %%
# Read in the clinical info
df_info = pd.read_excel('/content/BROWN急慢性判断ELVO_official.xlsx')
df_info.head(10)
# Out:
#   Organization  ... Total (Technical) (RVU)
# 0          RIH  ...                   11.58
# 1          RIH  ...                   11.58
# 2          NPH  ...                   11.58
# 3          TMH  ...                   11.58
# 4          RIH  ...                   11.58
# 5          TMH  ...                   11.58
# 6          RIH  ...                   11.58
# 7          RIH  ...                   11.58
# 8          RIH  ...                     NaN
# 9          TMH  ...                   11.58
#
# [10 rows x 83 columns]

# %%
# Find the maps between the Sham Accession number and the accession number
df_maps = df_keys[["_ShamAccessionNumber", "AccessionNumber"]]
# Peek
df_maps.head()
# Out:
#                _ShamAccessionNumber  AccessionNumber
# 0  21ed0c879d220c395782d92ab099d0d0         52470350
# 1  6741e5458a961e0925fcab2ec28033fa         52323283
# 2  ff1db88d057497f1cc88c9c5e8c652b4         50843620
# 3  5eab13429b5fcff64aa376bae816a6b0         51412958
# 4  6f2ee4da9a4c728225e25418c2b6857f         52913066

# %%
# Left Merge to extract the info
df_merged = df_maps.merge(df_info, left_on="AccessionNumber", right_on="Accession Number")

# %%
print("Len of extracted clinical info:" +str(len(df_merged)))
print("Len of keys:" +str(len(df_keys)))
print("Len of original Brown exel:" +str(len(df_info)))
# Out:
# Len of extracted clinical info:8356
# Len of keys:8356
# Len of original Brown exel:9005

# %%
df_merged.to_csv ('extracted_clinical_info.csv', index = False, header=True)
